# %% [markdown]
# <a href="https://colab.research.google.com/github/enriquez13/transformers-sentiment-analysis/blob/main/notebooks%20/01_load_and_clean_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Importar librerías
import pandas as pd
import numpy as np

# 2. Cargar el dataset desde GitHub
url = "https://raw.githubusercontent.com/enriquez13/transformers-sentiment-analysis/main/data/raw/reviews.csv"
df = pd.read_csv(url)

# 3. Ver primeros filas
print("Primeras filas del dataset:")
print(df.head())
print("\nInformación del dataset:")
print(df.info())
