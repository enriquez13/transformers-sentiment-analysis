# %%
# ====================================================
# 01 - SENTIMENT ANALYSIS WITH TRANSFORMERS
# Autor: Alejandro
# Proyecto: transformers-sentiment-analysis
# ====================================================

# -----------------------------
# 1. Instalación de librerías
# -----------------------------
# !pip install transformers -q
# !pip install datasets -q
# !pip install torch -q

# -----------------------------
# 2. Importar dependencias
# -----------------------------
from transformers import pipeline

# -----------------------------
# 3. Cargar modelo pre-entrenado
# -----------------------------
classifier = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

# -----------------------------
# 4. Ejemplo rápido
# -----------------------------
textos = [
    "I love using artificial intelligence!",
    "This is the worst product I have ever bought.",
    "I'm not sure how I feel about this."
]

resultados = classifier(textos)
resultados
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9993295669555664},
#  {'label': 'NEGATIVE', 'score': 0.9997852444648743},
#  {'label': 'NEGATIVE', 'score': 0.9992402791976929}]
